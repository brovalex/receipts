# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
services_path = os.path.abspath(os.path.join(os.path.dirname("__file__"),".."))
sys.path.append(services_path)
from services.price_scraper.modules.scraper import PriceScraper

# %%
scraper = PriceScraper('../')

# %%
scraper.retry_proof_capture("https://www.foodbasics.ca/aisles/pantry/condiments-toppings/bbq-marinade-sauces/bbq-sauce/p/068100078527")
# Out:
# '../services/price_scraper/tmp/screenshots/0_2025-03-21_17-15-20.png'

# %%
scraper.auto_scrape(81)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 scraper.auto_scrape(81)
#
# File ~/src/github.com/receipts/services/price_scraper/modules/scraper.py:327, in PriceScraper.auto_scrape(self, reference_item_id)
#     323 def auto_scrape(self, reference_item_id: int) -> bool:
#     324     """
#     325     Auto scrape a given reference item ID
#     326     """
# --> 327     products = self.scrape_search(reference_item_id)
#     328     target_product = self.get_cheapest(products)
#     329     target_product = self.scrape_product(reference_item_id, target_product)
#
# File ~/src/github.com/receipts/services/price_scraper/modules/scraper.py:303, in PriceScraper.scrape_search(self, reference_item_id)
#     299 def scrape_search(self, reference_item_id: int) -> dict:
#     300     """
#     301     Search products for a given reference item ID
#     302     """
# --> 303     reference_item = self.mapping_df[self.mapping_df['id'] == reference_item_id].iloc[0]
#     304     product_name = reference_item['product_name']
#     305     print(f"Scraping product: {product_name}")
#
# File ~/src/github.com/receipts/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/src/github.com/receipts/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File ~/src/github.com/receipts/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
