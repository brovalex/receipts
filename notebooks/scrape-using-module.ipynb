# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
services_path = os.path.abspath(os.path.join(os.path.dirname("__file__"),".."))
sys.path.append(services_path)
from services.price_scraper.modules.scraper import PriceScraper

# %%
scraper = PriceScraper('../')

# %%
# scraper.retry_proof_capture("https://www.foodbasics.ca/aisles/pantry/condiments-toppings/bbq-marinade-sauces/bbq-sauce/p/068100078527")

# %%
scraper.retry_proof_capture("http://whatismyipaddress.com/")

# %%
scraper.auto_scrape(9)
# Out:
# Scraping product: selection baking semi-sweet chocolate chips
# Searching for: selection baking semi-sweet chocolate chips
# Using proxy: ca.smartproxy.com:20144
# https://www.foodbasics.ca/search?filter=selection+baking+semi-sweet+chocolate+chips&sortOrder=price-asc
# {'name': 'Semi-Sweet Chocolate Chunks', 'quantity': 270.0, 'unitOfMeasure': 'g', 'price': 3.49, 'pricePerWeight': 0.012925925925925928, 'referenceUrl': 'https://www.foodbasics.ca/aisles/pantry/baking-ingredients/chocolate-cocoa/semi-sweet-chocolate-chunks/p/059749976374', 'createdAt': '2025-03-23T00:37:12.679Z'}
# {'name': 'Mini Semi-Sweet Chocolate Chips', 'quantity': 270.0, 'unitOfMeasure': 'g', 'price': 3.49, 'pricePerWeight': 0.012925925925925928, 'referenceUrl': 'https://www.foodbasics.ca/aisles/pantry/baking-ingredients/chocolate-cocoa/mini-semi-sweet-chocolate-chips/p/059749997041', 'createdAt': '2025-03-23T00:37:12.791Z'}
# {'name': 'Semi-Sweet Chocolate Chips', 'quantity': 270.0, 'unitOfMeasure': 'g', 'price': 3.49, 'pricePerWeight': 0.012925925925925928, 'referenceUrl': 'https://www.foodbasics.ca/aisles/pantry/baking-ingredients/chocolate-cocoa/semi-sweet-chocolate-chips/p/059749997089', 'createdAt': '2025-03-23T00:37:12.894Z'}
# {'name': 'Semi-Sweet Mini Chocolate Chips, Chipits', 'quantity': 270.0, 'unitOfMeasure': 'g', 'price': 4.49, 'pricePerWeight': 0.01662962962962963, 'referenceUrl': 'https://www.foodbasics.ca/aisles/pantry/baking-ingredients/chocolate-cocoa/semi-sweet-mini-chocolate-chips/p/056600902848', 'createdAt': '2025-03-23T00:37:12.985Z'}
# {'name': 'Semi-Sweet Chocolate Chips, Chipits', 'quantity': 270.0, 'unitOfMeasure': 'g', 'price': 4.49, 'pricePerWeight': 0.01662962962962963, 'referenceUrl': 'https://www.foodbasics.ca/aisles/pantry/baking-ingredients/chocolate-cocoa/semi-sweet-chocolate-chips/p/056600902886', 'createdAt': '2025-03-23T00:37:13.052Z'}
# {'name': 'Semi-Sweet Baking Chocolate', 'quantity': 200.0, 'unitOfMeasure': 'g', 'price': 4.79, 'pricePerWeight': 0.02395, 'referenceUrl': 'https://www.foodbasics.ca/aisles/pantry/baking-ingredients/chocolate-cocoa/semi-sweet-baking-chocolate/p/059749996976', 'createdAt': '2025-03-23T00:37:13.120Z'}
# {'name': 'Semi-Sweet Chocolate Chips', 'quantity': 925.0, 'unitOfMeasure': 'g', 'price': 10.99, 'pricePerWeight': 0.011881081081081081, 'referenceUrl': 'https://www.foodbasics.ca/aisles/pantry/baking-ingredients/chocolate-cocoa/semi-sweet-chocolate-chips/p/059749997096', 'createdAt': '2025-03-23T00:37:13.346Z'}
# Getting cheapest of 7 item(s):
# {'name': 'Semi-Sweet Chocolate Chips', 'quantity': 925.0, 'unitOfMeasure': 'g', 'price': 10.99, 'pricePerWeight': 0.011881081081081081, 'referenceUrl': 'https://www.foodbasics.ca/aisles/pantry/baking-ingredients/chocolate-cocoa/semi-sweet-chocolate-chips/p/059749997096', 'createdAt': '2025-03-23T00:37:13.346Z'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 scraper.auto_scrape(9)
#
# File ~/src/github.com/receipts/services/price_scraper/modules/scraper.py:335, in PriceScraper.auto_scrape(self, reference_item_id)
#     331 def auto_scrape(self, reference_item_id: int) -> bool:
#     332     """
#     333     Auto scrape a given reference item ID
#     334     """
# --> 335     products = self.scrape_search(reference_item_id)
#     336     target_product = self.get_cheapest(products)
#     337     target_product = self.scrape_product(reference_item_id, target_product)
#
# File ~/src/github.com/receipts/services/price_scraper/modules/scraper.py:314, in PriceScraper.scrape_search(self, reference_item_id)
#     312 product_name = reference_item['product_name']
#     313 print(f"Scraping product: {product_name}")
# --> 314 products = self.search_for_products(product_name)
#     315 if len(products) == 0:
#     316     print(f"No products found for {product_name}")
#
# File ~/src/github.com/receipts/services/price_scraper/modules/scraper.py:296, in PriceScraper.search_for_products(self, product_name)
#     293 target_product = self.get_cheapest(items)
#     295 # Highlight the target product tile and scroll it into view
# --> 296 target_tile = driver.find_elements(By.CLASS_NAME, 'default-product-tile')[target_product['index']]
#     297 driver.execute_script("arguments[0].style.border = '10px solid yellow';", target_tile)
#     298 driver.execute_script("arguments[0].scrollIntoView({behavior: 'smooth', block: 'center'});", target_tile)
#
# KeyError: 'index'
